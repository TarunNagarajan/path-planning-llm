# %%
# !nvidia-smi

# %%
# !pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu118
# !pip install open3d numpy matplotlib tqdm scipy
# !pip install onnx onnxruntime-gpu onnx-simplifier
# !pip install torch2trt tensorrt

# %%
import torch
print("CUDA Available:", torch.cuda.is_available())
print("GPU Name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU detected")
# Out:
# CUDA Available: True
# GPU Name: Tesla T4

# %%
import open3d as o3d
import numpy as np
import matplotlib.pyplot as plt

num_points = 1000
xyz = np.random.rand(num_points, 3)

pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(xyz)

xyz_np = np.asarray(pcd.points)

fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xyz_np[:, 0], xyz_np[:, 1], xyz_np[:, 2], s=2, c=xyz_np[:, 2], cmap="viridis")
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
plt.show()
